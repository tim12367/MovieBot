# %%
import json
movie_data = json.loads('[  {    "film_title": "幻幻之交 Imaginary Friends",    "movie_length": "104",    "release_date": "2024-05-15"  },  {    "film_title": "滅世男孩 Boy Kills World",    "movie_length": "100",    "release_date": "2024-05-17"  },  {    "film_title": "藍色恐懼 Perfect Blue",    "movie_length": "82",    "release_date": "2024-05-17"  },  {    "film_title": "日落喜劇 The Falling Star",    "movie_length": "100",    "release_date": "2024-05-17"  },  {    "film_title": "魯邦三世 卡里奧斯特羅城 Lupin III: The Castle of Cagliostro",    "movie_length": "100",    "release_date": "2024-05-17"  },  {    "film_title": "全面監視 Total Trust",    "movie_length": "97",    "release_date": "2024-05-17"  },  {    "film_title": "九龍城寨之圍城 Twilight of the Warriors: Walled In",    "movie_length": "120",    "release_date": "2024-05-17"  },  {    "film_title": "BLOODY ESCAPE:地獄的逃走劇 Bloody Escape",    "movie_length": "97",    "release_date": "2024-05-17"  },  {    "film_title": "如果可以再死一次 The First Day of My Life",    "movie_length": "121",    "release_date": "2024-05-17"  },  {    "film_title": "沉默筆錄 Records without Words",    "movie_length": "91",    "release_date": "2024-05-17"  },  {    "film_title": "鴉色刑事組電影版 Ichikeis Crow The Movie",    "movie_length": "119",    "release_date": "2024-05-17"  },  {    "film_title": "小熊維尼2：噬血 維尼 Winnie the Pooh: Blood and Honey 2",    "movie_length": "94",    "release_date": "2024-05-17"  },  {    "film_title": "芙莉歐莎：瘋狂麥斯傳奇篇章 Furiosa",    "release_date": "2024-05-22"  },  {    "film_title": "以愛之茗 Black Tea",    "release_date": "2024-05-24"  },  {    "film_title": "花芯蕩漾 Roadside Flowers and Grass",    "release_date": "2024-05-24"  },  {    "film_title": "她說 SHE\'s Talking, in Island",    "movie_length": "101",    "release_date": "2024-05-24"  },  {    "film_title": "蘇維埃巴士站 SOVIET BUS STOPS",    "movie_length": "60",    "release_date": "2024-05-24"  },  {    "film_title": "假面騎士555 20th 復活的天堂 Masked Rider 555 20th PARADISE REGAINED",    "release_date": "2024-05-24"  },  {    "film_title": "愛情本性論 The Nature of Love",    "movie_length": "111",    "release_date": "2024-05-24"  },  {    "film_title": "鬼舞村：詛咒起源 KKN: Badarawuhi Di Desa Penari",    "movie_length": "122",    "release_date": "2024-05-24"  },  {    "film_title": "刀劍亂舞 迴 虛傳 燃燒的本能寺 【前篇】 TOUKEN RANBU KAI",    "release_date": "2024-05-24"  },  {    "film_title": "踹你死功夫 The Invisible Fight",    "release_date": "2024-05-24"  },  {    "film_title": "失憶殺神 Knox Goes Away",    "movie_length": "114",    "release_date": "2024-05-31"  },  {    "film_title": "再見哥雅：卡葉爾與布紐爾的最後巡禮 Goya, Carriere & the Ghost of Bunuel",    "release_date": "2024-05-31"  },  {    "film_title": "她死了 Following",    "release_date": "2024-05-31"  },  {    "film_title": "波紋 Ripples",    "movie_length": "120",    "release_date": "2024-05-31"  },  {    "film_title": "環南時候 The Time of Huannan",    "release_date": "2024-05-31"  },  {    "film_title": "怒火狂猴 monkey man",    "release_date": "2024-05-31"  },  {    "film_title": "嗜殺路人甲 The Strangers: Chapter 1",    "release_date": "2024-05-31"  },  {    "film_title": "那日清晨真令人感到空虛 When Morning Comes, I Feel Empty",    "release_date": "2024-05-31"  },  {    "film_title": "八戒：決戰未來 Pigsy",    "movie_length": "96",    "release_date": "2024-05-31"  },  {    "film_title": "當殺手戀愛時 Hit Man",    "release_date": "2024-05-31"  },  {    "film_title": "絕地戰警：生死與共 Bad Boys 4",    "release_date": "2024-06-05"  },  {    "film_title": "明天我就不幹了 Mr. Blake at Your Service",    "release_date": "2024-06-07"  },  {    "film_title": "不 丹沒有槍 The Monk and the Gun",    "release_date": "2024-06-07"  },  {    "film_title": "加菲貓：農場大冒險 The Garfield Movie",    "release_date": "2024-06-07"  },  {    "film_title": "睏寐之際 The Sleep Goddess",    "movie_length": "79",    "release_date": "2024-06-07"  },  {    "film_title": "屍油降 The Spirit Hunter",    "release_date": "2024-06-07"  },  {    "film_title": "鬼咧號 Kereta Berdarah",    "movie_length": "103",    "release_date": "2024-06-07"  },  {    "film_title": "春畫先生 Picture of Spring",    "movie_length": "114",    "release_date": "2024-06-07"  },  {    "film_title": "腦筋急轉彎2 Inside Out 2",    "release_date": "2024-06-13"  },  {    "film_title": "窺探者 The Watchers",    "release_date": "2024-06-13"  },  {    "film_title": "刀劍亂舞 迴 -虛傳 燃燒的本能寺-【後篇】 TOUKEN RANBU KA",    "release_date": "2024-06-14"  },  {    "film_title": "托芙的房間 Tove\'s Room",    "movie_length": "73",    "release_date": "2024-06-14"  },  {    "film_title": "孤獨搖滾！團結Band LIVE-恆星 BOCCHI THE ROCK! Kessoku Band Concert",    "movie_length": "118",    "release_date": "2024-06-15"  },  {    "film_title": "2024台北電影節 2024 TAIPEI FILM FESTIVAL",    "release_date": "2024-06-21"  },  {    "film_title": "到我們為止 It Ends with Us",    "release_date": "2024-06-21"  },  {    "film_title": "金孫爆富攻略 How to make millions before grandma dies",    "release_date": "2024-06-21"  },  {    "film_title": "噤界：入侵日 A Quiet Place: Day One",    "release_date": "2024-06-26"  },  {    "film_title": "名偵探柯南 100萬美元的五稜星 Detective Conan The Movie: The Million-dollar Pentagram",    "release_date": "2024-06-28"  },  {    "film_title": "2024第15 屆兩岸電影展 The 15h Annual Cross-Strait Film Exhibition",    "release_date": "2024-06-28"  },  {    "film_title": "神偷奶爸4 Despicable Me 4",    "release_date": "2024-07-05"  },  {    "film_title": "我想和你在一起 Love Beside Me",    "release_date": "2024-07-05"  },  {    "film_title": "飛月情海 Fly Me to the Moon",    "release_date": "2024-07-10"  },  {    "film_title": "DDDD惡魔的破壞 前章 DEAD DEAD DEMONS DEDEDEDE DESTRUCTION Part 1",    "release_date": "2024-07-10"  }]')

# %%
import pandas as pd
movie_dataFrame = pd.DataFrame(movie_data)
movie_dataFrame
# Out:
#                                            film_title movie_length  \
# 0                              幻幻之交 Imaginary Friends          104
# 1                                滅世男孩 Boy Kills World          100
# 2                                   藍色恐懼 Perfect Blue           82
# 3                               日落喜劇 The Falling Star          100
# 4    魯邦三世 卡里奧斯特羅城 Lupin III: The Castle of Cagliostro          100
# 5                                    全面監視 Total Trust           97
# 6         九龍城寨之圍城 Twilight of the Warriors: Walled In          120
# 7                  BLOODY ESCAPE:地獄的逃走劇 Bloody Escape           97
# 8                   如果可以再死一次 The First Day of My Life          121
# 9                          沉默筆錄 Records without Words           91
# 10                   鴉色刑事組電影版 Ichikeis Crow The Movie          119
# 11     小熊維尼2：噬血 維尼 Winnie the Pooh: Blood and Honey 2           94
# 12                              芙莉歐莎：瘋狂麥斯傳奇篇章 Furiosa          NaN
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:1234@localhost/movie_bot?charset=utf8')
df = pd.read_sql('movie_info',engine)
df
# Out:
#   film_title movie_length release_date         create_date  \
# 0    test123           40   2024-05-14 2024-05-14 21:09:40
#
#           change_date  id
# 0 2024-05-14 21:09:40   1

# %%
movie_dataFrame.to_sql('movie_info', engine, schema = 'movie_bot', if_exists='append', index=False)
# Out:
# 55
